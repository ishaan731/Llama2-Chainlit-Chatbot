# %%
# !git clone https://github.com/ndn1954/Llama2-Chainlit-Chatbot
# %cd Llama2-Chainlit-Chatbot
# !pip install -r requirements.txt
# Out:
# Cloning into 'Llama2-Chainlit-Chatbot'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 21 (delta 4), reused 1 (delta 1), pack-reused 10
# Receiving objects: 100% (21/21), 21.53 MiB | 20.18 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/Llama2-Chainlit-Chatbot
# Collecting pypdf (from -r requirements.txt (line 1))
#   Downloading pypdf-3.15.4-py3-none-any.whl (272 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 4.3 MB/s eta 0:00:00
# Collecting langchain (from -r requirements.txt (line 2))
#   Downloading langchain-0.0.274-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 3)) (2.0.1+cu118)
# Collecting accelerate (from -r requirements.txt (line 4))
#   Downloading accelerate-0.22.0-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 10.6 MB/s eta 0:00:00
# Collecting bitsandbytes (from -r requirements.txt (line 5))
#   Downloading bitsandbytes-0.41.1-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.9 MB/s eta 0:00:00
# Collecting transformers (from -r requirements.txt (line 6))
#   Downloading transformers-4.32.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 26.1 MB/s eta 0:00:00
# Collecting sentence_transformers (from -r requirements.txt (line 7))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting faiss_cpu (from -r requirements.txt (line 8))
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 47.0 MB/s eta 0:00:00
# Collecting chainlit (from -r requirements.txt (line 9))
#   Downloading chainlit-0.6.3-py3-none-any.whl (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.3/771.3 kB 42.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (2.0.20)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (4.0.3)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain->-r requirements.txt (line 2))
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting langsmith<0.1.0,>=0.0.21 (from langchain->-r requirements.txt (line 2))
#   Downloading langsmith-0.0.27-py3-none-any.whl (34 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (2.8.5)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (8.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 3)) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 3)) (16.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 4)) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 4)) (5.9.5)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers->-r requirements.txt (line 6))
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 6)) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 6))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 90.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r requirements.txt (line 6))
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 7)) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 7)) (3.8.1)
# Collecting sentencepiece (from sentence_transformers->-r requirements.txt (line 7))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.7 MB/s eta 0:00:00
# Collecting aiofiles<24.0.0,>=23.1.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting asyncer<0.0.3,>=0.0.2 (from chainlit->-r requirements.txt (line 9))
#   Downloading asyncer-0.0.2-py3-none-any.whl (8.3 kB)
# Collecting auth0-python<5.0.0,>=4.4.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading auth0_python-4.4.1-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from chainlit->-r requirements.txt (line 9)) (8.1.7)
# Collecting fastapi<0.98.0,>=0.97.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading fastapi-0.97.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.1 MB/s eta 0:00:00
# Collecting fastapi-socketio<0.0.11,>=0.0.10 (from chainlit->-r requirements.txt (line 9))
#   Downloading fastapi_socketio-0.0.10-py3-none-any.whl (7.4 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting lazify<0.5.0,>=0.4.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading Lazify-0.4.0-py2.py3-none-any.whl (3.1 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from chainlit->-r requirements.txt (line 9)) (1.5.7)
# Collecting prisma<0.10.0,>=0.9.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading prisma-0.9.1-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 12.8 MB/s eta 0:00:00
# Collecting pydantic<3,>=1 (from langchain->-r requirements.txt (line 2))
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.5 MB/s eta 0:00:00
# Collecting python-dotenv<2.0.0,>=1.0.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting python-graphql-client<0.5.0,>=0.4.3 (from chainlit->-r requirements.txt (line 9))
#   Downloading python_graphql_client-0.4.3-py3-none-any.whl (4.9 kB)
# Collecting syncer<3.0.0,>=2.0.3 (from chainlit->-r requirements.txt (line 9))
#   Downloading syncer-2.0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from chainlit->-r requirements.txt (line 9)) (2.0.1)
# Collecting uptrace<2.0.0,>=1.18.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading uptrace-1.19.0-py3-none-any.whl (8.6 kB)
# Collecting uvicorn<0.23.0,>=0.22.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# Collecting watchfiles<0.20.0,>=0.19.0 (from chainlit->-r requirements.txt (line 9))
#   Downloading watchfiles-0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from asyncer<0.0.3,>=0.0.2->chainlit->-r requirements.txt (line 9)) (3.7.1)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.3 in /usr/local/lib/python3.10/dist-packages (from auth0-python<5.0.0,>=4.4.0->chainlit->-r requirements.txt (line 9)) (41.0.3)
# Collecting pyjwt<3.0.0,>=2.8.0 (from auth0-python<5.0.0,>=4.4.0->chainlit->-r requirements.txt (line 9))
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyopenssl<24.0.0,>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from auth0-python<5.0.0,>=4.4.0->chainlit->-r requirements.txt (line 9)) (23.2.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain->-r requirements.txt (line 2))
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain->-r requirements.txt (line 2))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.98.0,>=0.97.0->chainlit->-r requirements.txt (line 9))
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.5 MB/s eta 0:00:00
# Collecting python-socketio>=4.6.0 (from fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 9))
#   Downloading python_socketio-5.8.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers->-r requirements.txt (line 6)) (2023.6.0)
# Collecting httpx>=0.19.0 (from prisma<0.10.0,>=0.9.0->chainlit->-r requirements.txt (line 9))
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 9.3 MB/s eta 0:00:00
# Collecting tomlkit (from prisma<0.10.0,>=0.9.0->chainlit->-r requirements.txt (line 9))
#   Downloading tomlkit-0.12.1-py3-none-any.whl (37 kB)
# Collecting nodeenv (from prisma<0.10.0,>=0.9.0->chainlit->-r requirements.txt (line 9))
#   Downloading nodeenv-1.8.0-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r requirements.txt (line 3)) (2.1.3)
# Collecting websockets>=5.0 (from python-graphql-client<0.5.0,>=0.4.3->chainlit->-r requirements.txt (line 9))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 2)) (2.0.2)
# Collecting opentelemetry-api==1.19.0 (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_api-1.19.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.3 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp==1.19.0 (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_exporter_otlp-1.19.0-py3-none-any.whl (7.0 kB)
# Collecting opentelemetry-instrumentation==0.40b0 (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_instrumentation-0.40b0-py3-none-any.whl (25 kB)
# Collecting opentelemetry-sdk==1.19.0 (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_sdk-1.19.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 kB 11.1 MB/s eta 0:00:00
# Collecting deprecated>=1.2.6 (from opentelemetry-api==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata~=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9)) (6.8.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.19.0 (from opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.19.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.19.0 (from opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_exporter_otlp_proto_http-1.19.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.40b0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9)) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.40b0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9)) (1.14.1)
# Collecting opentelemetry-semantic-conventions==0.40b0 (from opentelemetry-sdk==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_semantic_conventions-0.40b0-py3-none-any.whl (26 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc==1.19.0->opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.19.0->opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9)) (1.60.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.19.0->opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9)) (1.57.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.19.0 (from opentelemetry-exporter-otlp-proto-grpc==1.19.0->opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_exporter_otlp_proto_common-1.19.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.19.0 (from opentelemetry-exporter-otlp-proto-grpc==1.19.0->opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9))
#   Downloading opentelemetry_proto-1.19.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<5.0,>=3.19 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-proto==1.19.0->opentelemetry-exporter-otlp-proto-grpc==1.19.0->opentelemetry-exporter-otlp==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9)) (3.20.3)
# Collecting h11>=0.8 (from uvicorn<0.23.0,>=0.22.0->chainlit->-r requirements.txt (line 9))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers->-r requirements.txt (line 7)) (9.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit->-r requirements.txt (line 9)) (1.1.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<42.0.0,>=41.0.3->auth0-python<5.0.0,>=4.4.0->chainlit->-r requirements.txt (line 9)) (1.15.1)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx>=0.19.0->prisma<0.10.0,>=0.9.0->chainlit->-r requirements.txt (line 9))
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.8 MB/s eta 0:00:00
# Collecting bidict>=0.21.0 (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 9))
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting python-engineio>=4.3.0 (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 9))
#   Downloading python_engineio-4.6.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 7.2 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain->-r requirements.txt (line 2))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.3->auth0-python<5.0.0,>=4.4.0->chainlit->-r requirements.txt (line 9)) (2.21)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata~=6.0->opentelemetry-api==1.19.0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 9)) (3.16.2)
# Building wheels for collected packages: sentence_transformers, syncer
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=0aae52664e00262f2ee2dcaeb10542830b6969e5a2b6f9b113f94a77f87a4a17
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for syncer (setup.py) ... done
#   Created wheel for syncer: filename=syncer-2.0.3-py2.py3-none-any.whl size=3437 sha256=11731b8d3e6097b1604ef380755f097c1c080dd8b976c788a344a618a884c07d
#   Stored in directory: /root/.cache/pip/wheels/09/e4/36/bcaad665bcc2b672888ff2df1a5a1dc638378d8765055313cd
# Successfully built sentence_transformers syncer
# Installing collected packages: tokenizers, syncer, sentencepiece, safetensors, lazify, filetype, faiss_cpu, bitsandbytes, websockets, tomlkit, python-engineio, python-dotenv, pypdf, pyjwt, pydantic, opentelemetry-semantic-conventions, opentelemetry-proto, nodeenv, mypy-extensions, marshmallow, h11, deprecated, bidict, backoff, aiofiles, watchfiles, uvicorn, typing-inspect, starlette, python-socketio, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, langsmith, huggingface-hub, httpcore, asyncer, transformers, python-graphql-client, opentelemetry-sdk, opentelemetry-instrumentation, httpx, fastapi, dataclasses-json, prisma, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, langchain, fastapi-socketio, auth0-python, opentelemetry-exporter-otlp, uptrace, chainlit, sentence_transformers, accelerate
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.2.1
#     Uninstalling pydantic-2.2.1:
#       Successfully uninstalled pydantic-2.2.1
# Successfully installed accelerate-0.22.0 aiofiles-23.2.1 asyncer-0.0.2 auth0-python-4.4.1 backoff-2.2.1 bidict-0.22.1 bitsandbytes-0.41.1 chainlit-0.6.3 dataclasses-json-0.5.14 deprecated-1.2.14 faiss_cpu-1.7.4 fastapi-0.97.0 fastapi-socketio-0.0.10 filetype-1.2.0 h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 huggingface-hub-0.16.4 langchain-0.0.274 langsmith-0.0.27 lazify-0.4.0 marshmallow-3.20.1 mypy-extensions-1.0.0 nodeenv-1.8.0 opentelemetry-api-1.19.0 opentelemetry-exporter-otlp-1.19.0 opentelemetry-exporter-otlp-proto-common-1.19.0 opentelemetry-exporter-otlp-proto-grpc-1.19.0 opentelemetry-exporter-otlp-proto-http-1.19.0 opentelemetry-instrumentation-0.40b0 opentelemetry-proto-1.19.0 opentelemetry-sdk-1.19.0 opentelemetry-semantic-conventions-0.40b0 prisma-0.9.1 pydantic-1.10.12 pyjwt-2.8.0 pypdf-3.15.4 python-dotenv-1.0.0 python-engineio-4.6.1 python-graphql-client-0.4.3 python-socketio-5.8.0 safetensors-0.3.3 sentence_transformers-2.2.2 sentencepiece-0.1.99 starlette-0.27.0 syncer-2.0.3 tokenizers-0.13.3 tomlkit-0.12.1 transformers-4.32.1 typing-inspect-0.9.0 uptrace-1.19.0 uvicorn-0.22.0 watchfiles-0.19.0 websockets-11.0.3

# %%
# !python ingest.py
# Out:
# Downloading (…)e9125/.gitattributes: 100% 1.18k/1.18k [00:00<00:00, 3.63MB/s]
# Downloading (…)_Pooling/config.json: 100% 190/190 [00:00<00:00, 695kB/s]
# Downloading (…)7e55de9125/README.md: 100% 10.6k/10.6k [00:00<00:00, 24.6MB/s]
# Downloading (…)55de9125/config.json: 100% 612/612 [00:00<00:00, 2.86MB/s]
# Downloading (…)ce_transformers.json: 100% 116/116 [00:00<00:00, 572kB/s]
# Downloading (…)125/data_config.json: 100% 39.3k/39.3k [00:00<00:00, 202kB/s]
# Downloading pytorch_model.bin: 100% 90.9M/90.9M [00:00<00:00, 208MB/s]
# Downloading (…)nce_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 215kB/s]
# Downloading (…)cial_tokens_map.json: 100% 112/112 [00:00<00:00, 457kB/s]
# Downloading (…)e9125/tokenizer.json: 100% 466k/466k [00:00<00:00, 791kB/s]
# Downloading (…)okenizer_config.json: 100% 350/350 [00:00<00:00, 1.65MB/s]
# Downloading (…)9125/train_script.py: 100% 13.2k/13.2k [00:00<00:00, 39.8MB/s]
# Downloading (…)7e55de9125/vocab.txt: 100% 232k/232k [00:00<00:00, 592kB/s]
# Downloading (…)5de9125/modules.json: 100% 349/349 [00:00<00:00, 1.69MB/s]
# 2023-08-28 16:46:24.327796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://y4z0eb4tdw-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
# !chainlit run model.py -w
# Out:
# 2023-08-28 16:57:11 - Created default config file at /content/Llama2-Chainlit-Chatbot/.chainlit/config.toml
# 2023-08-28 16:57:14 - Your app is available at http://localhost:8000
# 2023-08-28 16:57:32 - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2023-08-28 16:57:32 - Created a temporary directory at /tmp/tmpboty52vi
# 2023-08-28 16:57:32 - Writing /tmp/tmpboty52vi/_remote_module_non_scriptable.py
# 2023-08-28 16:57:33.814001: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-08-28 16:57:36 - Loading faiss with AVX2 support.
# 2023-08-28 16:57:36 - Successfully loaded faiss with AVX2 support.
# Downloading (…)chat.ggmlv3.q8_0.bin: 100% 7.16G/7.16G [01:22<00:00, 86.8MB/s]
# Batches: 100% 1/1 [00:00<00:00,  3.82it/s]
# 2023-08-28 17:03:45 - 3 changes detected
# Batches: 100% 1/1 [00:00<00:00, 23.33it/s]
# 2023-08-28 17:10:27 - 3 changes detected
# Batches: 100% 1/1 [00:00<00:00, 24.37it/s]
# 2023-08-28 17:14:59 - 3 changes detected
# ^C
